# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('creditcard.csv',encoding='latin-1')

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe().transpose()
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (283726, 31)

# %%
df['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
sns.countplot(x='Class',data=df)
plt.title("Class distribution for 0 and 1")
# Out:
# Text(0.5, 1.0, 'Class distribution for 0 and 1')

# %%
# from above graph we can clearly say that it is very imbalanced data as perspective of "Class" Column
# so for that we need to balanced it using smote technique wich used for minority oversampling

# %%
X = df.drop("Class", axis=1)
Y = df['Class']

# %%
# Split the dataset into training data and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (212794, 30)

# %%
Y_train.shape
# Out:
# (212794,)

# %%
X_test.shape
# Out:
# (70932, 30)

# %%
Y_test.shape
# Out:
# (70932,)

# %%
Y_train.value_counts()
# Out:
# 0    212433
# 1       361
# Name: Class, dtype: int64

# %%
Y_test.value_counts()
# Out:
# 0    70820
# 1      112
# Name: Class, dtype: int64

# %%
# we need to balanced the dataset

# %%
# for that we use the SMOTE technique.
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)

x_train, y_train = smote.fit_resample(X_train,Y_train)
x_test, y_test = smote.fit_resample(X_test,Y_test)

# %%
y_train.value_counts()
# Out:
# 0    212433
# 1    212433
# Name: Class, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    70820
# 1    70820
# Name: Class, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
model = LogisticRegression(max_iter=100)
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_test=model.predict(x_test)

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     70820
#            1       0.98      0.96      0.97     70820
#
#     accuracy                           0.97    141640
#    macro avg       0.97      0.97      0.97    141640
# weighted avg       0.97      0.97      0.97    141640

# %%
matrix=confusion_matrix(y_test, y_pred_test)
sns.heatmap(matrix,annot=True)
plt.show()
print(matrix)
# Out:
# [[69258  1562]
#  [ 2547 68273]]

# %%
df_final = x_test
df_final['Predicted_Fraud'] = y_pred_test
df_final
# Out:
#                  Time         V1        V2         V3        V4        V5  \
# 0        69195.000000   1.054379 -0.764756   0.160168  0.665587  1.113466
# 1        80769.000000  -4.805134  4.351191  -0.916135 -0.900752 -0.870777
# 2        41182.000000  -1.549833 -0.261143   1.556289 -2.037817 -0.366315
# 3          666.000000   0.216344  0.663182   1.303520  0.169219 -0.404266
# 4       160870.000000  -0.273365  0.825649   0.555674  0.384915  1.343842
# ...               ...        ...       ...        ...       ...       ...
# 141635   40959.697130  -3.922079  3.866140  -7.568731  7.577398 -3.854229
# 141636   48865.650883  -0.278835  1.484852  -2.266497  1.652809 -0.639920
# 141637   41184.616098  -7.086660  4.863443  -9.950534  7.855095 -6.850170
# 141638   30057.882512 -13.328860  6.879495 -11.033196  4.252491 -8.171336
# 141639   32768.702683  -0.787223  0.640522   1.023874  2.683450  0.151005
#
#               V6         V7        V8        V9  ...       V21       V22  \
# ...
